# %% [markdown]
# ## This is the Baseline Data Processing

# %% [markdown]
# ## 1. Load Library

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()

# %% [markdown]
# ## 2. Data Processing

# %% [markdown]
# ### 2.a Load the data

# %%
# load all files into data
# drop the last two columns which are 'na' for train & test data
# drop the last one column which are 'na' for RUL data (ground truth)

allfile = [i+str(j)+'.txt' for i in ['data/'+item \
                           for item in ['train_FD00','test_FD00','RUL_FD00']] \
                           for j in range(1,4+1)]
data = [pd.read_csv(file, sep=' ', header=None) for file in allfile]

[f.drop(f.columns[[-1, -2]], axis=1, inplace=True) for f in data[0:8]]
[t.drop(t.columns[[-1]], axis=1, inplace=True) for t in data[8:12]]

header = ['id','cycle'] + \
         ['setting'+str(i) for i in range(1,3+1)] + \
         ['sensor'+str(j) for j in range(1,21+1)]
        
for k in range(8): 
    data[k].columns = header

# %%
# shape of the data sets

pd.DataFrame(np.array([[np.shape(dd)[0] for dd in data], 
                       [np.shape(ff)[1] for ff in data]]),
             index=['#columns', '#rows'],
             columns=[string + str(h) for string in ['train','test','URL'] \
                                      for h in range(1,4+1)])
# Out:
#           train1  train2  train3  train4  test1  test2  test3  test4  URL1  \
# #columns   20631   53759   24720   61249  13096  33991  16596  41214   100
# #rows         26      26      26      26     26     26     26     26     1
#
#           URL2  URL3  URL4
# #columns   259   100   248
# #rows        1     1     1

# %%
# There are certain groups in each train/test data set
# review data information in train1

print('train1 groups = ', len(np.unique(data[0]['id'])))
data[0]['cycle'].groupby(data[0]['id']).describe()[0:4]
# Out:
# train1 groups =  100
#     count   mean        std  min    25%    50%     75%    max
# id
# 1   192.0   96.5  55.569776  1.0  48.75   96.5  144.25  192.0
# 2   287.0  144.0  82.993976  1.0  72.50  144.0  215.50  287.0
# 3   179.0   90.0  51.816986  1.0  45.50   90.0  134.50  179.0
# 4   189.0   95.0  54.703748  1.0  48.00   95.0  142.00  189.0

# %% [markdown]
# ### 2.b Create Labels

# %%
# number of warning cycle
# w1 gives warning at 30 cycles before eol (end of life)
# w2 gives 15

w1, w2 = 30, 15

# %% [markdown]
# #### Training data

# %%
# add columns of ;rul' (remaining useful life) = 'max' - 'cycle', for regression
# w1 = 1 on 30 remaining time series, for binary classification
# w2 = 1 on 30 remaining time series and 2 on 15 time series, for multi-class classification

for item in data[0:4]:
    item['rul'] = item.groupby('id')['cycle'].transform('max') - item['cycle']
    item['w1'] = np.where(item['rul'] > w1, 0, 1)
    item['w2'] = np.where(item['rul'] > w2, 0, 1)
    item['w2'] = item['w2'] + item['w1']

# %%
data[0][0:5]
# Out:
#    id  cycle  setting1  setting2  setting3  sensor1  sensor2  sensor3  \
# 0   1      1   -0.0007   -0.0004     100.0   518.67   641.82  1589.70
# 1   1      2    0.0019   -0.0003     100.0   518.67   642.15  1591.82
# 2   1      3   -0.0043    0.0003     100.0   518.67   642.35  1587.99
# 3   1      4    0.0007    0.0000     100.0   518.67   642.35  1582.79
# 4   1      5   -0.0019   -0.0002     100.0   518.67   642.37  1582.85
#
#    sensor4  sensor5 ...  sensor15  sensor16  sensor17  sensor18  sensor19  \
# 0  1400.60    14.62 ...    8.4195      0.03       392      2388     100.0
# 1  1403.14    14.62 ...    8.4318      0.03       392      2388     100.0
# 2  1404.20    14.62 ...    8.4178      0.03       390      2388     100.0
# 3  1401.87    14.62 ...    8.3682      0.03       392      2388     100.0
# 4  1406.22    14.62 ...    8.4294      0.03       393      2388     100.0
#
#    sensor20  sensor21  rul  w1  w2
# 0     39.06   23.4190  191   0   0
# 1     39.00   23.4236  190   0   0
# 2     38.95   23.3442  189   0   0
# 3     38.88   23.3739  188   0   0
# 4     38.90   23.4044  187   0   0
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Testing data

# %%
# handle ground truth data first

for truth in data[8:12]:
    truth.columns = ['truth']
    truth['id'] = truth.index + 1

# %%
# testing data 'rul' considers ground truth data from RUL_FD00*.txt
# 'index + 4' means moving from test data to RUL data

for index in range(4,8):
    data[index] = data[index].merge(data[index+4], on=['id'], how='left')
    data[index]['rul'] = data[index].groupby('id')['cycle'].transform('max') + data[index]['truth'] - data[index]['cycle']
    data[index]['w1'] = np.where(data[index]['rul'] > w1, 0, 1)
    data[index]['w2'] = np.where(data[index]['rul'] > w2, 0, 1)
    data[index]['w2'] = data[index]['w2'] + data[index]['w1']

# %%
data[5][data[5]['rul']<18][0:5]
# Out:
#      id  cycle  setting1  setting2  setting3  sensor1  sensor2  sensor3  \
# 709   5    146   42.0048    0.8414     100.0   445.00   550.31  1360.89
# 710   5    147   25.0023    0.6204      60.0   462.54   537.16  1266.46
# 711   5    148   42.0055    0.8400     100.0   445.00   550.81  1358.95
# 947   7    173    0.0010    0.0000     100.0   518.67   643.73  1590.42
# 948   7    174   42.0053    0.8400     100.0   445.00   550.01  1361.15
#
#      sensor4  sensor5 ...  sensor16  sensor17  sensor18  sensor19  sensor20  \
# 709  1131.67     3.91 ...      0.02       332      2212    100.00     10.44
# 710  1054.05     7.05 ...      0.02       310      1915     84.93     14.15
# 711  1140.34     3.91 ...      0.02       333      2212    100.00     10.34
# 947  1422.27    14.62 ...      0.03       395      2388    100.00     38.55
# 948  1137.18     3.91 ...      0.02       332      2212    100.00     10.59
#
#      sensor21  truth  rul  w1  w2
# 709    6.3453     15   17   1   1
# 710    8.5077     15   16   1   1
# 711    6.3601     15   15   1   2
# 947   23.1545      6   17   1   1
# 948    6.3392      6   16   1   1
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Baseline data is ready

# %%
# assign to separate data sets for easier to manage
train1,train2,train3,train4, test1,test2,test3,test4, RUL1,RUL2,RUL3,RUL4 = data

# %%
train1[0:1]
# Out:
#    id  cycle  setting1  setting2  setting3  sensor1  sensor2  sensor3  \
# 0   1      1   -0.0007   -0.0004     100.0   518.67   641.82   1589.7
#
#    sensor4  sensor5 ...  sensor15  sensor16  sensor17  sensor18  sensor19  \
# 0   1400.6    14.62 ...    8.4195      0.03       392      2388     100.0
#
#    sensor20  sensor21  rul  w1  w2
# 0     39.06    23.419  191   0   0
#
# [1 rows x 29 columns]

# %%
test1[0:1]
# Out:
#    id  cycle  setting1  setting2  setting3  sensor1  sensor2  sensor3  \
# 0   1      1    0.0023    0.0003     100.0   518.67   643.02  1585.29
#
#    sensor4  sensor5 ...  sensor16  sensor17  sensor18  sensor19  sensor20  \
# 0  1398.21    14.62 ...      0.03       392      2388     100.0     38.86
#
#    sensor21  truth  rul  w1  w2
# 0   23.3735    112  142   0   0
#
# [1 rows x 30 columns]

# %%
RUL1[0:1]
# Out:
#    truth  id
# 0    112   1

# %% [markdown]
# ### 2.c Explore the Data

# %%
# look at one group of training sensor data over cycle time 

_, axes = plt.subplots(7, 3, figsize=(15, 10), sharex=True)
for index, ax in enumerate(axes.ravel()):
    train1[train1['id']==1].plot(x='cycle', y='sensor'+str(index+1), ax=ax, color='gray', linewidth=0.5)
plt.show()

# %%
# look at 10 groups of sensor data over training cycle
# give insights to noise filter using moving average, will use in optimization phase

np.random.seed(1234)
random10 = np.random.choice(train1['id'].unique(), size=10, replace=False)
train1_random10 = train1[train1['id'].isin(random10)].copy()

_, axes1 = plt.subplots(7, 3, figsize=(15, 12), sharex=True)
for index1, ax1 in enumerate(axes1.ravel()):
    for unit_id, group in train1_random10.groupby('id'):
        (group
            .plot(x='cycle', y='sensor'+str(index1+1), ax=ax1, color='gray', linewidth=0.5, legend=False))
        (group
            .rolling(window=10, on = 'cycle')
            .mean()
            .plot(x='cycle', y='sensor'+str(index1+1), ax=ax1, color='black', linewidth=1, legend=False))
    ax1.set_title(('sensor'+str(index1+1)).title())

plt.tight_layout()
plt.show()

# %%
# look at 10 groups of sensor data till end of life
# red line is end of life

_, axes2 = plt.subplots(7, 3, figsize=(15, 12), sharex=True)
for index2, ax2 in enumerate(axes2.ravel()):
    for unit_id2, group2 in train1_random10.groupby('id'):
        (group2
            .plot(x='rul', y='sensor'+str(index2+1), ax=ax2, \
                     color='gray', linewidth=0.5, legend=False))
        (group2
            .rolling(window=10, on = 'rul')
            .mean()
            .plot(x='rul', y='sensor'+str(index2+1), ax=ax2, \
                  color='black', linewidth=1, legend=False))
    ax2.set_title(('sensor'+str(index2+1)).title())
    ax2.axvline(x=0, color='r', linestyle='solid', linewidth=2)
    ax2.set_xlim(train1_random10['rul'].max(), -10)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.d Filter Data

# %%
# From the data exploration
# sensor 1, 5, 6, 10, 16, 18, 19 are constant
# sensor 6 is both flat and only with noise
# Will drop these data

[dat.drop([str(name)], axis=1, inplace=True) \
     for dat in [train1, test1] \
     for name in ['sensor'+str(index3) \
     for index3 in [1,5,6,10,16,18,19]]]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
print(np.shape(train1))
train1[0:1]
# Out:
# (20631, 22)
#    id  cycle  setting1  setting2  setting3  sensor2  sensor3  sensor4  \
# 0   1      1   -0.0007   -0.0004     100.0   641.82   1589.7   1400.6
#
#    sensor7  sensor8 ...  sensor12  sensor13  sensor14  sensor15  sensor17  \
# 0   554.36  2388.06 ...    521.66   2388.02   8138.62    8.4195       392
#
#    sensor20  sensor21  rul  w1  w2
# 0     39.06    23.419  191   0   0
#
# [1 rows x 22 columns]

# %%
print(np.shape(test1))
test1[0:1]
# Out:
# (13096, 23)
#    id  cycle  setting1  setting2  setting3  sensor2  sensor3  sensor4  \
# 0   1      1    0.0023    0.0003     100.0   643.02  1585.29  1398.21
#
#    sensor7  sensor8 ...  sensor13  sensor14  sensor15  sensor17  sensor20  \
# 0    553.9  2388.04 ...   2388.03   8125.55    8.4052       392     38.86
#
#    sensor21  truth  rul  w1  w2
# 0   23.3735    112  142   0   0
#
# [1 rows x 23 columns]

# %%
# save dat sets to local disk as pickles

train1.to_pickle('data/train1.pkl')
test1.to_pickle('data/test1.pkl')
RUL1.to_pickle('data/RUL1.pkl')

# %% [markdown]
# ## This is the end of baseline data processing
